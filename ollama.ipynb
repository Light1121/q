# %%
# Eval code, adapted for jupyter notebook with backtest decorator
import numpy as np
import pandas as pd
from functools import wraps

nInst = 0
nt = 0
commRate = 0.0005
dlrPosLimit = 10000

def loadPrices(fn):
    global nt, nInst
    df=pd.read_csv(fn, sep=r'\s+', header=None, index_col=None)
    (nt,nInst) = df.shape
    return (df.values).T

pricesFile="./.data/2025/prices.txt"
prcAll = loadPrices(pricesFile)
print ("Loaded %d instruments for %d days" % (nInst, nt))

def calcPL(getPosition, prcHist=None, numTestDays=200):
    if prcHist is None:
        prcHist = prcAll
    
    cash = 0
    curPos = np.zeros(nInst)
    totDVolume = 0
    totDVolumeSignal = 0
    totDVolumeRandom = 0
    value = 0
    todayPLL = []
    (_,nt_local) = prcHist.shape
    startDay = nt_local + 1 - numTestDays
    
    for t in range(startDay, nt_local+1):
        prcHistSoFar = prcHist[:,:t]
        curPrices = prcHistSoFar[:,-1]
        if (t < nt_local):
            # Trading, do not do it on the very last day of the test
            newPosOrig = getPosition(prcHistSoFar)
            posLimits = np.array([int(x) for x in dlrPosLimit / curPrices])
            newPos = np.clip(newPosOrig, -posLimits, posLimits)
            deltaPos = newPos - curPos
            dvolumes = curPrices * np.abs(deltaPos)
            dvolume = np.sum(dvolumes)
            totDVolume += dvolume
            comm = dvolume * commRate
            cash -= curPrices.dot(deltaPos) + comm
        else:
            newPos = np.array(curPos)
        curPos = np.array(newPos)
        posValue = curPos.dot(curPrices)
        todayPL = cash + posValue - value
        value = cash + posValue
        ret = 0.0
        if (totDVolume > 0):
            ret = value / totDVolume
        if (t > startDay):
            print ("Day %d value: %.2lf todayPL: $%.2lf $-traded: %.0lf return: %.5lf" % (t,value, todayPL, totDVolume, ret))
            todayPLL.append(todayPL)
    
    pll = np.array(todayPLL)
    (plmu,plstd) = (np.mean(pll), np.std(pll))
    annSharpe = 0.0
    if (plstd > 0):
        annSharpe = np.sqrt(249) * plmu / plstd
    return (plmu, ret, plstd, annSharpe, totDVolume)

def backtest(numTestDays=200, prcHist=None, verbose=True):
    """
    Decorator to backtest a position function
    
    Args:
        numTestDays: Number of days to test (default 200)
        prcHist: Price history array (default uses global prcAll)
        verbose: Whether to print detailed results (default True)
    """
    def decorator(getPosition_func):
        @wraps(getPosition_func)
        def wrapper(*args, **kwargs):
            print(f"Testing function: {getPosition_func.__name__}")
            
            # Run the backtest
            (meanpl, ret, plstd, sharpe, dvol) = calcPL(
                getPosition_func, 
                prcHist if prcHist is not None else prcAll, 
                numTestDays
            )
            
            score = meanpl - 0.1*plstd
            
            if verbose:
                print ("=====")
                print (f"Function: {getPosition_func.__name__}")
                print ("mean(PL): %.1lf" % meanpl)
                print ("return: %.5lf" % ret)
                print ("StdDev(PL): %.2lf" % plstd)
                print ("annSharpe(PL): %.2lf " % sharpe)
                print ("totDvolume: %.0lf " % dvol)
                print ("Score: %.2lf" % score)
                print ("=====")
            
            # Store results as function attributes for later access
            wrapper.results = {
                'meanpl': meanpl,
                'return': ret,
                'plstd': plstd,
                'sharpe': sharpe,
                'dvol': dvol,
                'score': score
            }
            
            return wrapper.results
        
        # Run backtest immediately when decorator is applied
        wrapper()
        return wrapper
    
    return decorator
# Out:
# Loaded 50 instruments for 750 days

# %%
# Bit of a dumb/crazy idea but can we just ask an llm to think and make decisions for us?
import ollama
import numpy as np
import json

model = "llama3.2:3b"  # Using a more stable model

def get_llm_trading_decision(price_history, stock_id, current_day):
    """
    Ask LLM to analyze price data and make trading decisions
    """
    # Prepare price data for the LLM
    recent_prices = price_history[-10:].tolist()  # Last 10 days
    price_change = (price_history[-1] - price_history[-2]) / price_history[-2] * 100
    
    # Calculate some basic stats
    avg_price = np.mean(recent_prices)
    volatility = np.std(recent_prices)
    trend = "up" if recent_prices[-1] > recent_prices[0] else "down"
    
    prompt = f"""
You are a quantitative trader analyzing stock {stock_id} on day {current_day}.

Recent price data (last 10 days): {recent_prices}
Today's price change: {price_change:.2f}%
10-day average: {avg_price:.2f}
Volatility (std dev): {volatility:.2f}
Overall trend: {trend}

Based on this data, decide your position for this stock:
- Return a single integer between -10 and +10
- Positive = long position, Negative = short position, 0 = no position
- Consider momentum, mean reversion, volatility, and trend
- Be decisive but not reckless

Respond with ONLY a single integer, no explanation.
"""

    try:
        response = ollama.generate(model=model, prompt=prompt)
        decision_text = response['response'].strip()
        
        # Extract number from response
        import re
        numbers = re.findall(r'-?\d+', decision_text)
        if numbers:
            decision = int(numbers[0])
            return np.clip(decision, -10, 10)  # Ensure within bounds
        else:
            return 0  # Default to no position if can't parse
            
    except Exception as e:
        print(f"Error getting LLM decision for stock {stock_id}: {e}")
        return 0

@backtest()
def llm_trading_strategy(prcHistSoFar):
    """
    Trading strategy that uses LLM to make decisions for each stock
    """
    nInst, nt = prcHistSoFar.shape
    
    if nt < 5:  # Need some history
        return np.zeros(nInst)
    
    positions = np.zeros(nInst)
    
    print(f"Consulting LLM for trading decisions on day {nt}...")
    
    # Get LLM decision for each stock
    for stock_id in range(nInst):
        stock_prices = prcHistSoFar[stock_id, :]
        decision = get_llm_trading_decision(stock_prices, stock_id, nt)
        positions[stock_id] = decision
        
        # Optional: print some decisions for debugging
        if stock_id < 5:  # Only print first few
            print(f"Stock {stock_id}: Position {decision}")
    
    return positions
# Out:
# Testing function: llm_trading_strategy
# Consulting LLM for trading decisions on day 551...
# Stock 0: Position 8
# Stock 1: Position 6
# Stock 2: Position 5
# Stock 3: Position 3
# Stock 4: Position 5
# Consulting LLM for trading decisions on day 552...
# Stock 0: Position 4
# Stock 1: Position 3
# Stock 2: Position 5
# Stock 3: Position 5
# Stock 4: Position 5
# Day 552 value: -12.79 todayPL: $-6.89 $-traded: 16096 return: -0.00079
# Consulting LLM for trading decisions on day 553...
# Stock 0: Position 5
# Stock 1: Position 5
# Stock 2: Position 3
# Stock 3: Position 3
# Stock 4: Position 6
# Day 553 value: -11.77 todayPL: $1.02 $-traded: 20439 return: -0.00058
# Consulting LLM for trading decisions on day 554...
# Stock 0: Position 3
# Stock 1: Position 5
# Stock 2: Position 5
# Stock 3: Position 5
# Stock 4: Position 5
# Day 554 value: -28.24 todayPL: $-16.47 $-traded: 25506 return: -0.00111
# Consulting LLM for trading decisions on day 555...
# Stock 0: Position 5
# Stock 1: Position 3
# Stock 2: Position 5
# Stock 3: Position 5
# Stock 4: Position 4
# Day 555 value: -16.05 todayPL: $12.20 $-traded: 29174 return: -0.00055
# Consulting LLM for trading decisions on day 556...
# Stock 0: Position 4
# Stock 1: Position 5
# Stock 2: Position 5
# Stock 3: Position 5
# Stock 4: Position 3
# Day 556 value: -4.90 todayPL: $11.15 $-traded: 32273 return: -0.00015
# Consulting LLM for trading decisions on day 557...
# Stock 0: Position 3
# Stock 1: Position 6
# Stock 2: Position 5
# Stock 3: Position 5
# Stock 4: Position 2
# Day 557 value: -60.58 todayPL: $-55.68 $-traded: 34978 return: -0.00173
# Consulting LLM for trading decisions on day 558...
# Stock 0: Position 2
# Stock 1: Position 3
# Stock 2: Position 5
# Stock 3: Position -4
# Stock 4: Position 3
# Day 558 value: -78.78 todayPL: $-18.20 $-traded: 37922 return: -0.00208
# Consulting LLM for trading decisions on day 559...
# Stock 0: Position 5
# Stock 1: Position 6
# Stock 2: Position 6
# Stock 3: Position 5
# Stock 4: Position 8
# Day 559 value: -72.43 todayPL: $6.35 $-traded: 42140 return: -0.00172
# Consulting LLM for trading decisions on day 560...
# Stock 0: Position 6
# Stock 1: Position 3
# Stock 2: Position 5
# Stock 3: Position 5
# Stock 4: Position 5
# Day 560 value: -110.50 todayPL: $-38.07 $-traded: 46098 return: -0.00240
# Consulting LLM for trading decisions on day 561...
# Stock 0: Position 5
# Stock 1: Position 6
# Stock 2: Position 6
# Stock 3: Position 8
# Stock 4: Position 8
# Day 561 value: -134.03 todayPL: $-23.53 $-traded: 49616 return: -0.00270
# Consulting LLM for trading decisions on day 562...
# Stock 0: Position 3
# Stock 1: Position 5
# Stock 2: Position 4
# Stock 3: Position 3
# Stock 4: Position 5
# Day 562 value: -141.62 todayPL: $-7.60 $-traded: 53408 return: -0.00265
# Consulting LLM for trading decisions on day 563...
# Stock 0: Position 6
# Stock 1: Position 5
# Stock 2: Position 3
# Stock 3: Position 6
# Stock 4: Position 3
# Day 563 value: -136.05 todayPL: $5.58 $-traded: 56590 return: -0.00240
# Consulting LLM for trading decisions on day 564...
# Stock 0: Position 6
# Stock 1: Position 8
# Stock 2: Position 5
# Stock 3: Position 5
# Stock 4: Position 6
# Day 564 value: -157.13 todayPL: $-21.09 $-traded: 60424 return: -0.00260
# Consulting LLM for trading decisions on day 565...
# Stock 0: Position 5
# Stock 1: Position 3
# Stock 2: Position 5
# Stock 3: Position 5
# Stock 4: Position 8
# Day 565 value: -156.95 todayPL: $0.18 $-traded: 63425 return: -0.00247
# Consulting LLM for trading decisions on day 566...
# Stock 0: Position 3
# Stock 1: Position 5
# Stock 2: Position 5
# Stock 3: Position 5
# Stock 4: Position 5
# Day 566 value: -169.00 todayPL: $-12.04 $-traded: 67012 return: -0.00252
# Consulting LLM for trading decisions on day 567...
# Stock 0: Position 3
# Stock 1: Position 5
# Stock 2: Position 4
# Stock 3: Position 8
# Stock 4: Position 3
# Day 567 value: -191.58 todayPL: $-22.58 $-traded: 69941 return: -0.00274
# Consulting LLM for trading decisions on day 568...
# Stock 0: Position 5
# Stock 1: Position 3
# Stock 2: Position 4
# Stock 3: Position 5
# Stock 4: Position 6
# Day 568 value: -216.31 todayPL: $-24.73 $-traded: 73325 return: -0.00295
# Consulting LLM for trading decisions on day 569...
# Stock 0: Position 8
# Stock 1: Position 6
# Stock 2: Position 3
# Stock 3: Position 4
# Stock 4: Position 5
# Day 569 value: -218.11 todayPL: $-1.80 $-traded: 76826 return: -0.00284
# Consulting LLM for trading decisions on day 570...
# Stock 0: Position 3
# Stock 1: Position 4
# Stock 2: Position 5
# Stock 3: Position 5
# Stock 4: Position 5
# Day 570 value: -222.63 todayPL: $-4.52 $-traded: 80405 return: -0.00277
# Consulting LLM for trading decisions on day 571...
# Stock 0: Position 3
# Stock 1: Position 4
# Stock 2: Position 5
# Stock 3: Position 3
# Stock 4: Position 3
# Day 571 value: -203.61 todayPL: $19.02 $-traded: 83424 return: -0.00244
# Consulting LLM for trading decisions on day 572...
# Stock 0: Position 5
# Stock 1: Position 3
# Stock 2: Position 6
# Stock 3: Position 5
# Stock 4: Position 5
# Day 572 value: -214.49 todayPL: $-10.88 $-traded: 86469 return: -0.00248
# Consulting LLM for trading decisions on day 573...
# Stock 0: Position 5
# Stock 1: Position 3
# Stock 2: Position 5
# Stock 3: Position 4
# Stock 4: Position 3
# Day 573 value: -222.27 todayPL: $-7.78 $-traded: 88700 return: -0.00251
# Consulting LLM for trading decisions on day 574...
# Stock 0: Position 6
# Stock 1: Position 3
# Stock 2: Position 6
# Stock 3: Position 3
# Stock 4: Position 3
# Day 574 value: -223.11 todayPL: $-0.84 $-traded: 91188 return: -0.00245
# Consulting LLM for trading decisions on day 575...
# Stock 0: Position 5
# Stock 1: Position 5
# Stock 2: Position 6
# Stock 3: Position 3
# Stock 4: Position 3
# Day 575 value: -234.89 todayPL: $-11.77 $-traded: 93193 return: -0.00252
# Consulting LLM for trading decisions on day 576...
# Stock 0: Position 3
# Stock 1: Position 4
# Stock 2: Position 6
# Stock 3: Position 3
# Stock 4: Position 4
# Day 576 value: -253.22 todayPL: $-18.33 $-traded: 96190 return: -0.00263
# Consulting LLM for trading decisions on day 577...
# Stock 0: Position 5
# Stock 1: Position 4
# Stock 2: Position 6
# Stock 3: Position 3
# Stock 4: Position 8
# Day 577 value: -274.04 todayPL: $-20.82 $-traded: 99260 return: -0.00276
# Consulting LLM for trading decisions on day 578...
# Stock 0: Position 3
# Stock 1: Position 4
# Stock 2: Position 6
# Stock 3: Position 4
# Stock 4: Position 5
# Day 578 value: -256.76 todayPL: $17.28 $-traded: 102662 return: -0.00250
# Consulting LLM for trading decisions on day 579...
# Stock 0: Position 5
# Stock 1: Position 3
# Stock 2: Position 3
# Stock 3: Position 5
# Stock 4: Position 6
# Day 579 value: -271.83 todayPL: $-15.07 $-traded: 106126 return: -0.00256
# Consulting LLM for trading decisions on day 580...
# Stock 0: Position 6
# Stock 1: Position 3
# Stock 2: Position 4
# Stock 3: Position 6
# Stock 4: Position 5
# Day 580 value: -267.19 todayPL: $4.64 $-traded: 109159 return: -0.00245
# Consulting LLM for trading decisions on day 581...
# Stock 0: Position 6
# Stock 1: Position 3
# Stock 2: Position 8
# Stock 3: Position 5
# Stock 4: Position 3
# Day 581 value: -254.52 todayPL: $12.67 $-traded: 112405 return: -0.00226
# Consulting LLM for trading decisions on day 582...
# Stock 0: Position 3
# Stock 1: Position 5
# Stock 2: Position 3
# Stock 3: Position 2
# Stock 4: Position 6
# Day 582 value: -264.96 todayPL: $-10.44 $-traded: 115985 return: -0.00228
# Consulting LLM for trading decisions on day 583...
# Stock 0: Position 6
# Stock 1: Position 3
# Stock 2: Position 4
# Stock 3: Position 4
# Stock 4: Position 5
# Day 583 value: -258.09 todayPL: $6.88 $-traded: 119673 return: -0.00216
# Consulting LLM for trading decisions on day 584...
# Stock 0: Position 3
# Stock 1: Position 4
# Stock 2: Position 5
# Stock 3: Position 6
# Stock 4: Position 3
# Day 584 value: -273.15 todayPL: $-15.06 $-traded: 122815 return: -0.00222
# Consulting LLM for trading decisions on day 585...
# Stock 0: Position 4
# Stock 1: Position 5
# Stock 2: Position 6
# Stock 3: Position 5
# Stock 4: Position 5
# Day 585 value: -260.09 todayPL: $13.06 $-traded: 126216 return: -0.00206
# Consulting LLM for trading decisions on day 586...
# Stock 0: Position 4
# Stock 1: Position 5
# Stock 2: Position 5
# Stock 3: Position 5
# Stock 4: Position 3
# Day 586 value: -289.33 todayPL: $-29.24 $-traded: 129419 return: -0.00224
# Consulting LLM for trading decisions on day 587...
# Stock 0: Position 8
# Stock 1: Position 5
# Stock 2: Position 5
# Stock 3: Position 5
# Stock 4: Position 5
# Day 587 value: -300.04 todayPL: $-10.71 $-traded: 132449 return: -0.00227
# Consulting LLM for trading decisions on day 588...
# Stock 0: Position 5
# Stock 1: Position 4
# Stock 2: Position 5
# Stock 3: Position 6
# Stock 4: Position 8
# Day 588 value: -339.24 todayPL: $-39.19 $-traded: 136457 return: -0.00249
# Consulting LLM for trading decisions on day 589...
# Stock 0: Position 3
# Stock 1: Position 5
# Stock 2: Position 5
# Stock 3: Position 5
# Stock 4: Position 2
# Day 589 value: -354.49 todayPL: $-15.26 $-traded: 140427 return: -0.00252
# Consulting LLM for trading decisions on day 590...
# Stock 0: Position 6
# Stock 1: Position 6
# Stock 2: Position 4
# Stock 3: Position 5
# Stock 4: Position 3
# Day 590 value: -360.46 todayPL: $-5.97 $-traded: 144064 return: -0.00250
# Consulting LLM for trading decisions on day 591...
# Stock 0: Position 3
# Stock 1: Position 3
# Stock 2: Position 5
# Stock 3: Position 5
# Stock 4: Position 3
# Day 591 value: -359.34 todayPL: $1.12 $-traded: 147230 return: -0.00244
# Consulting LLM for trading decisions on day 592...
# Stock 0: Position 5
# Stock 1: Position 8
# Stock 2: Position 3
# Stock 3: Position 6
# Stock 4: Position 6
# Day 592 value: -388.13 todayPL: $-28.79 $-traded: 151502 return: -0.00256
# Consulting LLM for trading decisions on day 593...
# Stock 0: Position 6
# Stock 1: Position 5
# Stock 2: Position 5
# Stock 3: Position 5
# Stock 4: Position 5
# Day 593 value: -409.55 todayPL: $-21.42 $-traded: 154694 return: -0.00265
# Consulting LLM for trading decisions on day 594...
# Stock 0: Position 3
# Stock 1: Position 4
# Stock 2: Position 5
# Stock 3: Position 5
# Stock 4: Position 3
# Day 594 value: -422.80 todayPL: $-13.25 $-traded: 158435 return: -0.00267
# Consulting LLM for trading decisions on day 595...
# Stock 0: Position 3
# Stock 1: Position 3
# Stock 2: Position 6
# Stock 3: Position 5
# Stock 4: Position 5
# Day 595 value: -424.76 todayPL: $-1.97 $-traded: 161649 return: -0.00263
# Consulting LLM for trading decisions on day 596...
# Stock 0: Position 3
# Stock 1: Position 4
# Stock 2: Position 6
# Stock 3: Position 5
# Stock 4: Position 8
# Day 596 value: -415.91 todayPL: $8.86 $-traded: 164998 return: -0.00252
# Consulting LLM for trading decisions on day 597...
# Stock 0: Position 6
# Stock 1: Position 3
# Stock 2: Position 4
# Stock 3: Position 5
# Stock 4: Position 3
# Day 597 value: -444.16 todayPL: $-28.25 $-traded: 168312 return: -0.00264
# Consulting LLM for trading decisions on day 598...
# Stock 0: Position 5
# Stock 1: Position 6
# Stock 2: Position 4
# Stock 3: Position 5
# Stock 4: Position 5
# Day 598 value: -475.91 todayPL: $-31.75 $-traded: 171855 return: -0.00277
# Consulting LLM for trading decisions on day 599...
# Stock 0: Position 5
# Stock 1: Position 4
# Stock 2: Position 6
# Stock 3: Position 6
# Stock 4: Position 3
# Day 599 value: -490.68 todayPL: $-14.77 $-traded: 175352 return: -0.00280
# Consulting LLM for trading decisions on day 600...
# Stock 0: Position 5
# Stock 1: Position 3
# Stock 2: Position 5
# Stock 3: Position 5
# Stock 4: Position 6
# Day 600 value: -510.14 todayPL: $-19.47 $-traded: 178804 return: -0.00285
# Consulting LLM for trading decisions on day 601...
# Stock 0: Position 3
# Stock 1: Position 5
# Stock 2: Position 8
# Stock 3: Position 5
# Stock 4: Position 3
# Day 601 value: -524.77 todayPL: $-14.63 $-traded: 181883 return: -0.00289
# Consulting LLM for trading decisions on day 602...
# Stock 0: Position 3
# Stock 1: Position 5
# Stock 2: Position 3
# Stock 3: Position 6
# Stock 4: Position 6
# Day 602 value: -508.41 todayPL: $16.36 $-traded: 184660 return: -0.00275
# Consulting LLM for trading decisions on day 603...
# Stock 0: Position 5
# Stock 1: Position 4
# Stock 2: Position 4
# Stock 3: Position 6
# Stock 4: Position 3
# Day 603 value: -476.63 todayPL: $31.78 $-traded: 187663 return: -0.00254
# Consulting LLM for trading decisions on day 604...
# Stock 0: Position 3
# Stock 1: Position 5
# Stock 2: Position 5
# Stock 3: Position 5
# Stock 4: Position 5
# Day 604 value: -465.83 todayPL: $10.80 $-traded: 190377 return: -0.00245
# Consulting LLM for trading decisions on day 605...
# Stock 0: Position 3
# Stock 1: Position 6
# Stock 2: Position 3
# Stock 3: Position 5
# Stock 4: Position 4
# Day 605 value: -468.66 todayPL: $-2.83 $-traded: 193660 return: -0.00242
# Consulting LLM for trading decisions on day 606...
# Stock 0: Position 4
# Stock 1: Position 5
# Stock 2: Position 6
# Stock 3: Position 3
# Stock 4: Position 5
# Day 606 value: -472.32 todayPL: $-3.66 $-traded: 197124 return: -0.00240
# Consulting LLM for trading decisions on day 607...
# Stock 0: Position 3
# Stock 1: Position 4
# Stock 2: Position 5
# Stock 3: Position 5
# Stock 4: Position 6
# Day 607 value: -499.11 todayPL: $-26.79 $-traded: 199886 return: -0.00250
# Consulting LLM for trading decisions on day 608...
# Stock 0: Position 5
# Stock 1: Position 5
# Stock 2: Position 6
# Stock 3: Position 6
# Stock 4: Position 5
# Day 608 value: -531.51 todayPL: $-32.40 $-traded: 203246 return: -0.00262
# Consulting LLM for trading decisions on day 609...
# Stock 0: Position 5
# Stock 1: Position 3
# Stock 2: Position 4
# Stock 3: Position 4
# Stock 4: Position 4
# Day 609 value: -552.77 todayPL: $-21.26 $-traded: 206577 return: -0.00268
# Consulting LLM for trading decisions on day 610...
# Stock 0: Position 3
# Stock 1: Position 3
# Stock 2: Position 5
# Stock 3: Position 4
# Stock 4: Position 3
# Day 610 value: -567.10 todayPL: $-14.33 $-traded: 210180 return: -0.00270
# Consulting LLM for trading decisions on day 611...
# Stock 0: Position 5
# Stock 1: Position 3
# Stock 2: Position 5
# Stock 3: Position 3
# Stock 4: Position 4
# Day 611 value: -571.46 todayPL: $-4.36 $-traded: 213329 return: -0.00268
# Consulting LLM for trading decisions on day 612...
# Stock 0: Position 3
# Stock 1: Position 5
# Stock 2: Position 5
# Stock 3: Position 6
# Stock 4: Position 4
# Day 612 value: -574.09 todayPL: $-2.63 $-traded: 216960 return: -0.00265
# Consulting LLM for trading decisions on day 613...
# Stock 0: Position 5
# Stock 1: Position 4
# Stock 2: Position 4
# Stock 3: Position 4
# Stock 4: Position 3
# Day 613 value: -592.42 todayPL: $-18.33 $-traded: 220048 return: -0.00269
# Consulting LLM for trading decisions on day 614...
# Stock 0: Position 5
# Stock 1: Position 4
# Stock 2: Position 5
# Stock 3: Position 5
# Stock 4: Position 4
# Day 614 value: -598.23 todayPL: $-5.81 $-traded: 222787 return: -0.00269
# Consulting LLM for trading decisions on day 615...
# Stock 0: Position 6
# Stock 1: Position 6
# Stock 2: Position 3
# Stock 3: Position 4
# Stock 4: Position 4
# Day 615 value: -588.59 todayPL: $9.64 $-traded: 226101 return: -0.00260
# Consulting LLM for trading decisions on day 616...
# Stock 0: Position 5
# Stock 1: Position 6
# Stock 2: Position 3
# Stock 3: Position 5
# Stock 4: Position 6
# Day 616 value: -607.34 todayPL: $-18.74 $-traded: 230150 return: -0.00264
# Consulting LLM for trading decisions on day 617...
# Stock 0: Position 6
# Stock 1: Position 8
# Stock 2: Position 5
# Stock 3: Position 6
# Stock 4: Position 3
# Day 617 value: -610.15 todayPL: $-2.81 $-traded: 233653 return: -0.00261
# Consulting LLM for trading decisions on day 618...
# Stock 0: Position 3
# Stock 1: Position 5
# Stock 2: Position 3
# Stock 3: Position 5
# Stock 4: Position 6
# Day 618 value: -598.77 todayPL: $11.38 $-traded: 237339 return: -0.00252
# Consulting LLM for trading decisions on day 619...
# Stock 0: Position 6
# Stock 1: Position 6
# Stock 2: Position 6
# Stock 3: Position 5
# Stock 4: Position 5
# Day 619 value: -619.08 todayPL: $-20.31 $-traded: 240460 return: -0.00257
# Consulting LLM for trading decisions on day 620...
# Stock 0: Position 5
# Stock 1: Position 6
# Stock 2: Position 3
# Stock 3: Position 5
# Stock 4: Position 5
# Day 620 value: -621.95 todayPL: $-2.87 $-traded: 243378 return: -0.00256
# Consulting LLM for trading decisions on day 621...
# Stock 0: Position 6
# Stock 1: Position 5
# Stock 2: Position 3
# Stock 3: Position 5
# Stock 4: Position 5
# Day 621 value: -628.82 todayPL: $-6.87 $-traded: 245948 return: -0.00256
# Consulting LLM for trading decisions on day 622...
# Stock 0: Position 3
# Stock 1: Position 5
# Stock 2: Position 4
# Stock 3: Position 5
# Stock 4: Position 3
# Day 622 value: -629.25 todayPL: $-0.43 $-traded: 249181 return: -0.00253
# Consulting LLM for trading decisions on day 623...
# Stock 0: Position 3
# Stock 1: Position 8
# Stock 2: Position 5
# Stock 3: Position 5
# Stock 4: Position 5
# Day 623 value: -646.15 todayPL: $-16.90 $-traded: 253555 return: -0.00255
# Consulting LLM for trading decisions on day 624...
# Stock 0: Position 6
# Stock 1: Position 3
# Stock 2: Position 3
# Stock 3: Position 5
# Stock 4: Position 5
# Day 624 value: -611.54 todayPL: $34.61 $-traded: 256684 return: -0.00238
# Consulting LLM for trading decisions on day 625...
# Stock 0: Position 3
# Stock 1: Position 5
# Stock 2: Position 4
# Stock 3: Position 5
# Stock 4: Position 3
# Day 625 value: -595.45 todayPL: $16.09 $-traded: 260187 return: -0.00229
# Consulting LLM for trading decisions on day 626...
# Stock 0: Position 5
# Stock 1: Position 5
# Stock 2: Position 5
# Stock 3: Position 8
# Stock 4: Position 3
# Day 626 value: -582.37 todayPL: $13.08 $-traded: 263138 return: -0.00221
# Consulting LLM for trading decisions on day 627...
# Stock 0: Position 3
# Stock 1: Position 5
# Stock 2: Position 4
# Stock 3: Position 5
# Stock 4: Position 3
# Day 627 value: -541.52 todayPL: $40.85 $-traded: 265820 return: -0.00204
# Consulting LLM for trading decisions on day 628...
# Stock 0: Position 2
# Stock 1: Position 3
# Stock 2: Position 6
# Stock 3: Position 4
# Stock 4: Position 5
# Day 628 value: -518.79 todayPL: $22.73 $-traded: 269419 return: -0.00193
# Consulting LLM for trading decisions on day 629...
# Stock 0: Position 6
# Stock 1: Position 5
# Stock 2: Position 5
# Stock 3: Position 4
# Stock 4: Position 5
# Day 629 value: -502.61 todayPL: $16.18 $-traded: 272905 return: -0.00184
# Consulting LLM for trading decisions on day 630...
# Stock 0: Position 3
# Stock 1: Position 5
# Stock 2: Position 5
# Stock 3: Position 5
# Stock 4: Position 4
# Day 630 value: -473.90 todayPL: $28.72 $-traded: 276013 return: -0.00172
# Consulting LLM for trading decisions on day 631...
# Stock 0: Position 4
# Stock 1: Position 5
# Stock 2: Position 3
# Stock 3: Position 6
# Stock 4: Position 4
# Day 631 value: -447.62 todayPL: $26.28 $-traded: 279111 return: -0.00160
# Consulting LLM for trading decisions on day 632...
# Stock 0: Position 6
# Stock 1: Position 3
# Stock 2: Position 4
# Stock 3: Position 8
# Stock 4: Position 3
# Day 632 value: -440.81 todayPL: $6.81 $-traded: 282477 return: -0.00156
# Consulting LLM for trading decisions on day 633...
# Stock 0: Position 4
# Stock 1: Position 5
# Stock 2: Position 6
# Stock 3: Position 4
# Stock 4: Position 6
# Day 633 value: -430.85 todayPL: $9.96 $-traded: 286233 return: -0.00151
# Consulting LLM for trading decisions on day 634...
# Stock 0: Position 3
# Stock 1: Position 3
# Stock 2: Position 5
# Stock 3: Position 5
# Stock 4: Position 4
# Day 634 value: -424.43 todayPL: $6.42 $-traded: 289437 return: -0.00147
# Consulting LLM for trading decisions on day 635...
# Stock 0: Position 5
# Stock 1: Position 6
# Stock 2: Position 5
# Stock 3: Position 6
# Stock 4: Position 6
# Day 635 value: -401.77 todayPL: $22.66 $-traded: 292424 return: -0.00137
# Consulting LLM for trading decisions on day 636...
# Stock 0: Position 3
# Stock 1: Position 3
# Stock 2: Position 3
# Stock 3: Position 5
# Stock 4: Position 3
# Day 636 value: -423.04 todayPL: $-21.27 $-traded: 295477 return: -0.00143
# Consulting LLM for trading decisions on day 637...
# Stock 0: Position 4
# Stock 1: Position 5
# Stock 2: Position 3
# Stock 3: Position 3
# Stock 4: Position 6
# Day 637 value: -424.62 todayPL: $-1.59 $-traded: 298908 return: -0.00142
# Consulting LLM for trading decisions on day 638...
# Stock 0: Position 5
# Stock 1: Position 3
# Stock 2: Position 6
# Stock 3: Position 5
# Stock 4: Position 6
# Day 638 value: -451.39 todayPL: $-26.77 $-traded: 302169 return: -0.00149
# Consulting LLM for trading decisions on day 639...
# Stock 0: Position 5
# Stock 1: Position 5
# Stock 2: Position 6
# Stock 3: Position 3
# Stock 4: Position -6
# Day 639 value: -463.52 todayPL: $-12.12 $-traded: 305497 return: -0.00152
# Consulting LLM for trading decisions on day 640...
# Stock 0: Position 5
# Stock 1: Position 3
# Stock 2: Position 5
# Stock 3: Position 6
# Stock 4: Position 5
# Day 640 value: -466.94 todayPL: $-3.42 $-traded: 308739 return: -0.00151
# Consulting LLM for trading decisions on day 641...
# Stock 0: Position 3
# Stock 1: Position 4
# Stock 2: Position 6
# Stock 3: Position 6
# Stock 4: Position -8
# Day 641 value: -442.98 todayPL: $23.96 $-traded: 312087 return: -0.00142
# Consulting LLM for trading decisions on day 642...
# Stock 0: Position 5
# Stock 1: Position 5
# Stock 2: Position 5
# Stock 3: Position 6
# Stock 4: Position 3
# Day 642 value: -437.60 todayPL: $5.39 $-traded: 315994 return: -0.00138
# Consulting LLM for trading decisions on day 643...
# Stock 0: Position 2
# Stock 1: Position 5
# Stock 2: Position 4
# Stock 3: Position 4
# Stock 4: Position 3
# Day 643 value: -448.40 todayPL: $-10.80 $-traded: 319475 return: -0.00140
# Consulting LLM for trading decisions on day 644...
# Stock 0: Position 6
# Stock 1: Position 3
# Stock 2: Position 3
# Stock 3: Position 5
# Stock 4: Position 6
# Day 644 value: -440.00 todayPL: $8.40 $-traded: 322800 return: -0.00136
# Consulting LLM for trading decisions on day 645...
# Stock 0: Position 5
# Stock 1: Position 5
# Stock 2: Position 5
# Stock 3: Position 4
# Stock 4: Position 5
# Day 645 value: -428.46 todayPL: $11.54 $-traded: 326066 return: -0.00131
# Consulting LLM for trading decisions on day 646...
# Stock 0: Position 5
# Stock 1: Position 4
# Stock 2: Position 8
# Stock 3: Position 4
# Stock 4: Position 4
# Day 646 value: -434.13 todayPL: $-5.67 $-traded: 329083 return: -0.00132
# Consulting LLM for trading decisions on day 647...
# Stock 0: Position 4
# Stock 1: Position 3
# Stock 2: Position 5
# Stock 3: Position 3
# Stock 4: Position 6
# Day 647 value: -429.12 todayPL: $5.02 $-traded: 333091 return: -0.00129
# Consulting LLM for trading decisions on day 648...
# Stock 0: Position 4
# Stock 1: Position 3
# Stock 2: Position 3
# Stock 3: Position 5
# Stock 4: Position 5
# Day 648 value: -438.44 todayPL: $-9.33 $-traded: 337226 return: -0.00130
# Consulting LLM for trading decisions on day 649...
# Stock 0: Position 5
# Stock 1: Position 3
# Stock 2: Position 3
# Stock 3: Position 6
# Stock 4: Position 5
# Day 649 value: -450.34 todayPL: $-11.90 $-traded: 341383 return: -0.00132
# Consulting LLM for trading decisions on day 650...
# Stock 0: Position 3
# Stock 1: Position 4
# Stock 2: Position 6
# Stock 3: Position 5
# Stock 4: Position 5
# Day 650 value: -462.35 todayPL: $-12.01 $-traded: 344282 return: -0.00134
# Consulting LLM for trading decisions on day 651...
# Stock 0: Position 6
# Stock 1: Position 5
# Stock 2: Position 4
# Stock 3: Position 5
# Stock 4: Position 5
# Day 651 value: -445.27 todayPL: $17.08 $-traded: 347578 return: -0.00128
# Consulting LLM for trading decisions on day 652...
# Stock 0: Position 8
# Stock 1: Position 5
# Stock 2: Position 6
# Stock 3: Position 4
# Stock 4: Position 3
# Day 652 value: -443.24 todayPL: $2.03 $-traded: 350917 return: -0.00126
# Consulting LLM for trading decisions on day 653...
# Stock 0: Position 5
# Stock 1: Position 6
# Stock 2: Position 3
# Stock 3: Position 6
# Stock 4: Position 6
# Day 653 value: -405.11 todayPL: $38.13 $-traded: 354694 return: -0.00114
# Consulting LLM for trading decisions on day 654...
# Stock 0: Position 5
# Stock 1: Position 6
# Stock 2: Position 3
# Stock 3: Position 5
# Stock 4: Position 5
# Day 654 value: -394.82 todayPL: $10.29 $-traded: 357757 return: -0.00110
# Consulting LLM for trading decisions on day 655...
# Stock 0: Position 5
# Stock 1: Position 4
# Stock 2: Position 3
# Stock 3: Position 5
# Stock 4: Position 5
# Day 655 value: -383.31 todayPL: $11.51 $-traded: 361203 return: -0.00106
# Consulting LLM for trading decisions on day 656...
# Stock 0: Position 5
# Stock 1: Position 3
# Stock 2: Position 5
# Stock 3: Position 6
# Stock 4: Position 3
# Day 656 value: -365.96 todayPL: $17.35 $-traded: 365055 return: -0.00100
# Consulting LLM for trading decisions on day 657...
# Stock 0: Position 3
# Stock 1: Position 6
# Stock 2: Position 3
# Stock 3: Position 6
# Stock 4: Position 5
# Day 657 value: -349.84 todayPL: $16.12 $-traded: 368313 return: -0.00095
# Consulting LLM for trading decisions on day 658...
# Stock 0: Position 5
# Stock 1: Position 7
# Stock 2: Position 4
# Stock 3: Position 5
# Stock 4: Position 6
# Day 658 value: -360.42 todayPL: $-10.59 $-traded: 371704 return: -0.00097
# Consulting LLM for trading decisions on day 659...
# Stock 0: Position 6
# Stock 1: Position 6
# Stock 2: Position 3
# Stock 3: Position 5
# Stock 4: Position 5
# Day 659 value: -334.70 todayPL: $25.72 $-traded: 374635 return: -0.00089
# Consulting LLM for trading decisions on day 660...
# Stock 0: Position 5
# Stock 1: Position 3
# Stock 2: Position 5
# Stock 3: Position 5
# Stock 4: Position 4
# Day 660 value: -337.55 todayPL: $-2.85 $-traded: 377592 return: -0.00089
# Consulting LLM for trading decisions on day 661...
# Stock 0: Position 5
# Stock 1: Position 5
# Stock 2: Position 5
# Stock 3: Position 3
# Stock 4: Position 3
# Day 661 value: -322.90 todayPL: $14.64 $-traded: 380886 return: -0.00085
# Consulting LLM for trading decisions on day 662...
# Stock 0: Position 5
# Stock 1: Position 3
# Stock 2: Position 3
# Stock 3: Position 6
# Stock 4: Position 5
# Day 662 value: -341.24 todayPL: $-18.34 $-traded: 385579 return: -0.00089
# Consulting LLM for trading decisions on day 663...
# Stock 0: Position 5
# Stock 1: Position 3
# Stock 2: Position 3
# Stock 3: Position 2
# Stock 4: Position 3
# Day 663 value: -346.42 todayPL: $-5.18 $-traded: 388678 return: -0.00089
# Consulting LLM for trading decisions on day 664...
# Stock 0: Position 2
# Stock 1: Position 5
# Stock 2: Position 4
# Stock 3: Position 3
# Stock 4: Position 6
# Day 664 value: -335.16 todayPL: $11.26 $-traded: 391968 return: -0.00086
# Consulting LLM for trading decisions on day 665...
# Stock 0: Position 4
# Stock 1: Position 5
# Stock 2: Position 3
# Stock 3: Position 5
# Stock 4: Position 5
# Day 665 value: -331.78 todayPL: $3.39 $-traded: 395277 return: -0.00084
# Consulting LLM for trading decisions on day 666...
# Stock 0: Position 6
# Stock 1: Position 4
# Stock 2: Position 5
# Stock 3: Position -8
# Stock 4: Position 3
# Day 666 value: -356.18 todayPL: $-24.40 $-traded: 399062 return: -0.00089
# Consulting LLM for trading decisions on day 667...
# Stock 0: Position 5
# Stock 1: Position 6
# Stock 2: Position 4
# Stock 3: Position 5
# Stock 4: Position 3
# Day 667 value: -359.12 todayPL: $-2.94 $-traded: 402102 return: -0.00089
# Consulting LLM for trading decisions on day 668...
# Stock 0: Position 3
# Stock 1: Position 6
# Stock 2: Position 3
# Stock 3: Position 4
# Stock 4: Position 5
# Day 668 value: -378.18 todayPL: $-19.06 $-traded: 405423 return: -0.00093
# Consulting LLM for trading decisions on day 669...
# Stock 0: Position 6
# Stock 1: Position 5
# Stock 2: Position 6
# Stock 3: Position 3
# Stock 4: Position 6
# Day 669 value: -397.60 todayPL: $-19.41 $-traded: 409312 return: -0.00097
# Consulting LLM for trading decisions on day 670...
# Stock 0: Position 5
# Stock 1: Position 4
# Stock 2: Position 6
# Stock 3: Position 5
# Stock 4: Position 6
# Day 670 value: -427.93 todayPL: $-30.33 $-traded: 412717 return: -0.00104
# Consulting LLM for trading decisions on day 671...
# Stock 0: Position 6
# Stock 1: Position 3
# Stock 2: Position 5
# Stock 3: Position 5
# Stock 4: Position 3
# Day 671 value: -455.83 todayPL: $-27.90 $-traded: 416456 return: -0.00109
# Consulting LLM for trading decisions on day 672...
# Stock 0: Position 5
# Stock 1: Position 6
# Stock 2: Position 3
# Stock 3: Position 5
# Stock 4: Position 5
# Day 672 value: -460.11 todayPL: $-4.28 $-traded: 419821 return: -0.00110
# Consulting LLM for trading decisions on day 673...
# Stock 0: Position 5
# Stock 1: Position 4
# Stock 2: Position 6
# Stock 3: Position 5
# Stock 4: Position 6
# Day 673 value: -444.20 todayPL: $15.91 $-traded: 422599 return: -0.00105
# Consulting LLM for trading decisions on day 674...
# Stock 0: Position 5
# Stock 1: Position 4
# Stock 2: Position 6
# Stock 3: Position 6
# Stock 4: Position 5
# Day 674 value: -425.00 todayPL: $19.20 $-traded: 426017 return: -0.00100
# Consulting LLM for trading decisions on day 675...
# Stock 0: Position 5
# Stock 1: Position 5
# Stock 2: Position 8
# Stock 3: Position 5
# Stock 4: Position 4
# Day 675 value: -424.80 todayPL: $0.19 $-traded: 429289 return: -0.00099
# Consulting LLM for trading decisions on day 676...
# Stock 0: Position 3
# Stock 1: Position 5
# Stock 2: Position 5
# Stock 3: Position 5
# Stock 4: Position 3
# Day 676 value: -417.85 todayPL: $6.96 $-traded: 432656 return: -0.00097
# Consulting LLM for trading decisions on day 677...
# Stock 0: Position 5
# Stock 1: Position 5
# Stock 2: Position 3
# Stock 3: Position 5
# Stock 4: Position 6
# Day 677 value: -441.33 todayPL: $-23.49 $-traded: 436209 return: -0.00101
# Consulting LLM for trading decisions on day 678...
# Stock 0: Position 5
# Stock 1: Position 5
# Stock 2: Position 4
# Stock 3: Position 4
# Stock 4: Position 6
# Day 678 value: -468.95 todayPL: $-27.61 $-traded: 439613 return: -0.00107
# Consulting LLM for trading decisions on day 679...
# Stock 0: Position 3
# Stock 1: Position 5
# Stock 2: Position 5
# Stock 3: Position 5
# Stock 4: Position 6
# Day 679 value: -480.47 todayPL: $-11.53 $-traded: 442908 return: -0.00108
# Consulting LLM for trading decisions on day 680...
# Stock 0: Position 3
# Stock 1: Position 5
# Stock 2: Position 3
# Stock 3: Position 5
# Stock 4: Position 3
# Day 680 value: -494.71 todayPL: $-14.24 $-traded: 446000 return: -0.00111
# Consulting LLM for trading decisions on day 681...
# Stock 0: Position 6
# Stock 1: Position 4
# Stock 2: Position 4
# Stock 3: Position 3
# Stock 4: Position 4
# Day 681 value: -494.02 todayPL: $0.69 $-traded: 449246 return: -0.00110
# Consulting LLM for trading decisions on day 682...
# Stock 0: Position 6
# Stock 1: Position 6
# Stock 2: Position 4
# Stock 3: Position 6
# Stock 4: Position 3
# Day 682 value: -502.62 todayPL: $-8.60 $-traded: 452558 return: -0.00111
# Consulting LLM for trading decisions on day 683...
# Stock 0: Position 5
# Stock 1: Position -6
# Stock 2: Position 3
# Stock 3: Position 3
# Stock 4: Position 6
# Day 683 value: -522.10 todayPL: $-19.48 $-traded: 457064 return: -0.00114
# Consulting LLM for trading decisions on day 684...
# Stock 0: Position 6
# Stock 1: Position 5
# Stock 2: Position 3
# Stock 3: Position 5
# Stock 4: Position 6
# Day 684 value: -547.21 todayPL: $-25.11 $-traded: 460622 return: -0.00119
# Consulting LLM for trading decisions on day 685...
# Stock 0: Position 5
# Stock 1: Position 6
# Stock 2: Position 6
# Stock 3: Position 6
# Stock 4: Position 3
# Day 685 value: -535.03 todayPL: $12.18 $-traded: 464466 return: -0.00115
# Consulting LLM for trading decisions on day 686...
# Stock 0: Position 5
# Stock 1: Position 3
# Stock 2: Position 3
# Stock 3: Position 5
# Stock 4: Position 6
# Day 686 value: -527.66 todayPL: $7.37 $-traded: 468257 return: -0.00113
# Consulting LLM for trading decisions on day 687...
# Stock 0: Position 3
# Stock 1: Position 5
# Stock 2: Position 5
# Stock 3: Position 4
# Stock 4: Position 6
# Day 687 value: -519.14 todayPL: $8.52 $-traded: 471043 return: -0.00110
# Consulting LLM for trading decisions on day 688...
# Stock 0: Position 3
# Stock 1: Position 4
# Stock 2: Position 3
# Stock 3: Position 5
# Stock 4: Position 8
# Day 688 value: -509.39 todayPL: $9.75 $-traded: 473961 return: -0.00107
# Consulting LLM for trading decisions on day 689...
# Stock 0: Position 3
# Stock 1: Position 5
# Stock 2: Position 6
# Stock 3: Position 6
# Stock 4: Position 3
# Day 689 value: -540.24 todayPL: $-30.85 $-traded: 477182 return: -0.00113
# Consulting LLM for trading decisions on day 690...
# Stock 0: Position 4
# Stock 1: Position 5
# Stock 2: Position 5
# Stock 3: Position 5
# Stock 4: Position 3
# Day 690 value: -550.17 todayPL: $-9.92 $-traded: 479852 return: -0.00115
# Consulting LLM for trading decisions on day 691...
# Stock 0: Position 6
# Stock 1: Position 2
# Stock 2: Position 5
# Stock 3: Position 6
# Stock 4: Position 5
# Day 691 value: -588.81 todayPL: $-38.65 $-traded: 484187 return: -0.00122
# Consulting LLM for trading decisions on day 692...
# Stock 0: Position 2
# Stock 1: Position 5
# Stock 2: Position 3
# Stock 3: Position 6
# Stock 4: Position 6
# Day 692 value: -618.89 todayPL: $-30.08 $-traded: 488440 return: -0.00127
# Consulting LLM for trading decisions on day 693...
# Stock 0: Position 3
# Stock 1: Position 6
# Stock 2: Position 5
# Stock 3: Position 3
# Stock 4: Position 5
# Day 693 value: -587.85 todayPL: $31.04 $-traded: 491830 return: -0.00120
# Consulting LLM for trading decisions on day 694...
# Stock 0: Position 5
# Stock 1: Position 5
# Stock 2: Position 6
# Stock 3: Position 6
# Stock 4: Position 5
# Day 694 value: -578.39 todayPL: $9.46 $-traded: 494870 return: -0.00117
# Consulting LLM for trading decisions on day 695...
# Stock 0: Position 5
# Stock 1: Position 6
# Stock 2: Position 3
# Stock 3: Position 5
# Stock 4: Position 3
# Day 695 value: -577.23 todayPL: $1.16 $-traded: 497593 return: -0.00116
# Consulting LLM for trading decisions on day 696...
# Stock 0: Position 5
# Stock 1: Position 6
# Stock 2: Position 5
# Stock 3: Position 5
# Stock 4: Position 5
# Day 696 value: -600.20 todayPL: $-22.98 $-traded: 500469 return: -0.00120
# Consulting LLM for trading decisions on day 697...
# Stock 0: Position 4
# Stock 1: Position 5
# Stock 2: Position 3
# Stock 3: Position 3
# Stock 4: Position 6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 56
#      53         print(f"Error getting LLM decision for stock {stock_id}: {e}")
#      54         return 0
# ---> 56 @backtest()
#      57 def llm_trading_strategy(prcHistSoFar):
#      58     """
#      59     Trading strategy that uses LLM to make decisions for each stock
#      60     """
#      61     nInst, nt = prcHistSoFar.shape
#
# Cell In[2], line 116, in backtest.<locals>.decorator(getPosition_func)
#     113     return wrapper.results
#     115 # Run backtest immediately when decorator is applied
# --> 116 wrapper()
#     117 return wrapper
#
# Cell In[2], line 84, in backtest.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      81 print(f"Testing function: {getPosition_func.__name__}")
#      83 # Run the backtest
# ---> 84 (meanpl, ret, plstd, sharpe, dvol) = calcPL(
#      85     getPosition_func,
#      86     prcHist if prcHist is not None else prcAll,
#      87     numTestDays
#      88 )
#      90 score = meanpl - 0.1*plstd
#      92 if verbose:
#
# Cell In[2], line 40, in calcPL(getPosition, prcHist, numTestDays)
#      37 curPrices = prcHistSoFar[:,-1]
#      38 if (t < nt_local):
#      39     # Trading, do not do it on the very last day of the test
# ---> 40     newPosOrig = getPosition(prcHistSoFar)
#      41     posLimits = np.array([int(x) for x in dlrPosLimit / curPrices])
#      42     newPos = np.clip(newPosOrig, -posLimits, posLimits)
#
# Cell In[3], line 73, in llm_trading_strategy(prcHistSoFar)
#      71 for stock_id in range(nInst):
#      72     stock_prices = prcHistSoFar[stock_id, :]
# ---> 73     decision = get_llm_trading_decision(stock_prices, stock_id, nt)
#      74     positions[stock_id] = decision
#      76     # Optional: print some decisions for debugging
#
# Cell In[3], line 40, in get_llm_trading_decision(price_history, stock_id, current_day)
#      21     prompt = f"""
#      22 You are a quantitative trader analyzing stock {stock_id} on day {current_day}.
#      23
#    (...)
#      36 Respond with ONLY a single integer, no explanation.
#      37 """
#      39     try:
# ---> 40         response = ollama.generate(model=model, prompt=prompt)
#      41         decision_text = response['response'].strip()
#      43         # Extract number from response
#
# File c:\Users\tranh\AppData\Local\Programs\Python\Python313\Lib\site-packages\ollama\_client.py:242, in Client.generate(self, model, prompt, suffix, system, template, context, stream, raw, format, images, options, keep_alive)
#     216 def generate(
#     217   self,
#     218   model: str = '',
#    (...)
#     230   keep_alive: Optional[Union[float, str]] = None,
#     231 ) -> Union[GenerateResponse, Iterator[GenerateResponse]]:
#     232   """
#     233   Create a response using the requested model.
#     234
#    (...)
#     239   Returns `GenerateResponse` if `stream` is `False`, otherwise returns a `GenerateResponse` generator.
#     240   """
# --> 242   return self._request(
#     243     GenerateResponse,
#     244     'POST',
#     245     '/api/generate',
#     246     json=GenerateRequest(
#     247       model=model,
#     248       prompt=prompt,
#     249       suffix=suffix,
#     250       system=system,
#     251       template=template,
#     252       context=context,
#     253       stream=stream,
#     254       raw=raw,
#     255       format=format,
#     256       images=[image for image in _copy_images(images)] if images else None,
#     257       options=options,
#     258       keep_alive=keep_alive,
#     259     ).model_dump(exclude_none=True),
#     260     stream=stream,
#     261   )
#
# File c:\Users\tranh\AppData\Local\Programs\Python\Python313\Lib\site-packages\ollama\_client.py:178, in Client._request(self, cls, stream, *args, **kwargs)
#     174         yield cls(**part)
#     176   return inner()
# --> 178 return cls(**self._request_raw(*args, **kwargs).json())
#
# File c:\Users\tranh\AppData\Local\Programs\Python\Python313\Lib\site-packages\ollama\_client.py:118, in Client._request_raw(self, *args, **kwargs)
#     116 def _request_raw(self, *args, **kwargs):
#     117   try:
# --> 118     r = self._client.request(*args, **kwargs)
#     119     r.raise_for_status()
#     120     return r
#
# File ~\AppData\Roaming\Python\Python313\site-packages\httpx\_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)
#     823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~\AppData\Roaming\Python\Python313\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\httpcore\_sync\http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~\AppData\Roaming\Python\Python313\site-packages\httpcore\_sync\http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~\AppData\Roaming\Python\Python313\site-packages\httpcore\_sync\http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~\AppData\Roaming\Python\Python313\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:
