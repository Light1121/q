# %%
# Eval code, adapted for jupyter notebook with backtest decorator
import numpy as np
import pandas as pd
from functools import wraps

nInst = 0
nt = 0
commRate = 0.0005
dlrPosLimit = 10000

def loadPrices(fn):
    global nt, nInst
    df=pd.read_csv(fn, sep=r'\s+', header=None, index_col=None)
    (nt,nInst) = df.shape
    return (df.values).T

pricesFile="./.data/2025/prices.txt"
prcAll = loadPrices(pricesFile)
print ("Loaded %d instruments for %d days" % (nInst, nt))

def calcPL(getPosition, prcHist=None, numTestDays=200):
    if prcHist is None:
        prcHist = prcAll
    
    cash = 0
    curPos = np.zeros(nInst)
    totDVolume = 0
    totDVolumeSignal = 0
    totDVolumeRandom = 0
    value = 0
    todayPLL = []
    (_,nt_local) = prcHist.shape
    startDay = nt_local + 1 - numTestDays
    
    for t in range(startDay, nt_local+1):
        prcHistSoFar = prcHist[:,:t]
        curPrices = prcHistSoFar[:,-1]
        if (t < nt_local):
            # Trading, do not do it on the very last day of the test
            newPosOrig = getPosition(prcHistSoFar)
            posLimits = np.array([int(x) for x in dlrPosLimit / curPrices])
            newPos = np.clip(newPosOrig, -posLimits, posLimits)
            deltaPos = newPos - curPos
            dvolumes = curPrices * np.abs(deltaPos)
            dvolume = np.sum(dvolumes)
            totDVolume += dvolume
            comm = dvolume * commRate
            cash -= curPrices.dot(deltaPos) + comm
        else:
            newPos = np.array(curPos)
        curPos = np.array(newPos)
        posValue = curPos.dot(curPrices)
        todayPL = cash + posValue - value
        value = cash + posValue
        ret = 0.0
        if (totDVolume > 0):
            ret = value / totDVolume
        if (t > startDay):
            print ("Day %d value: %.2lf todayPL: $%.2lf $-traded: %.0lf return: %.5lf" % (t,value, todayPL, totDVolume, ret))
            todayPLL.append(todayPL)
    
    pll = np.array(todayPLL)
    (plmu,plstd) = (np.mean(pll), np.std(pll))
    annSharpe = 0.0
    if (plstd > 0):
        annSharpe = np.sqrt(249) * plmu / plstd
    return (plmu, ret, plstd, annSharpe, totDVolume)

def backtest(numTestDays=200, prcHist=None, verbose=True):
    """
    Decorator to backtest a position function
    
    Args:
        numTestDays: Number of days to test (default 200)
        prcHist: Price history array (default uses global prcAll)
        verbose: Whether to print detailed results (default True)
    """
    def decorator(getPosition_func):
        @wraps(getPosition_func)
        def wrapper(*args, **kwargs):
            print(f"Testing function: {getPosition_func.__name__}")
            
            # Run the backtest
            (meanpl, ret, plstd, sharpe, dvol) = calcPL(
                getPosition_func, 
                prcHist if prcHist is not None else prcAll, 
                numTestDays
            )
            
            score = meanpl - 0.1*plstd
            
            if verbose:
                print ("=====")
                print (f"Function: {getPosition_func.__name__}")
                print ("mean(PL): %.1lf" % meanpl)
                print ("return: %.5lf" % ret)
                print ("StdDev(PL): %.2lf" % plstd)
                print ("annSharpe(PL): %.2lf " % sharpe)
                print ("totDvolume: %.0lf " % dvol)
                print ("Score: %.2lf" % score)
                print ("=====")
            
            # Store results as function attributes for later access
            wrapper.results = {
                'meanpl': meanpl,
                'return': ret,
                'plstd': plstd,
                'sharpe': sharpe,
                'dvol': dvol,
                'score': score
            }
            
            return wrapper.results
        
        # Run backtest immediately when decorator is applied
        wrapper()
        return wrapper
    
    return decorator
# Out:
# Loaded 50 instruments for 750 days

# %%
@backtest()
def simple_long_position(prcHistSoFar):
    """Simple strategy: always long 1 share of each stock"""
    nInst = prcHistSoFar.shape[0]
    return np.ones(nInst)
# Out:
# Testing function: simple_long_position
# Day 552 value: -4.31 todayPL: $-3.08 $-traded: 2462 return: -0.00175
# Day 553 value: -5.12 todayPL: $-0.81 $-traded: 2462 return: -0.00208
# Day 554 value: -8.58 todayPL: $-3.46 $-traded: 2462 return: -0.00349
# Day 555 value: -5.13 todayPL: $3.45 $-traded: 2462 return: -0.00208
# Day 556 value: -5.90 todayPL: $-0.77 $-traded: 2462 return: -0.00240
# Day 557 value: -16.58 todayPL: $-10.68 $-traded: 2462 return: -0.00674
# Day 558 value: -19.75 todayPL: $-3.17 $-traded: 2462 return: -0.00802
# Day 559 value: -18.38 todayPL: $1.37 $-traded: 2462 return: -0.00747
# Day 560 value: -26.68 todayPL: $-8.30 $-traded: 2462 return: -0.01084
# Day 561 value: -30.60 todayPL: $-3.92 $-traded: 2462 return: -0.01243
# Day 562 value: -31.75 todayPL: $-1.15 $-traded: 2462 return: -0.01290
# Day 563 value: -32.52 todayPL: $-0.77 $-traded: 2462 return: -0.01321
# Day 564 value: -36.40 todayPL: $-3.88 $-traded: 2462 return: -0.01479
# Day 565 value: -36.23 todayPL: $0.17 $-traded: 2462 return: -0.01472
# Day 566 value: -39.57 todayPL: $-3.34 $-traded: 2462 return: -0.01607
# Day 567 value: -44.27 todayPL: $-4.70 $-traded: 2462 return: -0.01798
# Day 568 value: -49.90 todayPL: $-5.63 $-traded: 2462 return: -0.02027
# Day 569 value: -50.20 todayPL: $-0.30 $-traded: 2462 return: -0.02039
# Day 570 value: -50.80 todayPL: $-0.60 $-traded: 2462 return: -0.02064
# Day 571 value: -45.83 todayPL: $4.97 $-traded: 2462 return: -0.01862
# Day 572 value: -46.69 todayPL: $-0.86 $-traded: 2462 return: -0.01897
# Day 573 value: -47.97 todayPL: $-1.28 $-traded: 2462 return: -0.01949
# Day 574 value: -47.76 todayPL: $0.21 $-traded: 2462 return: -0.01940
# Day 575 value: -50.15 todayPL: $-2.39 $-traded: 2462 return: -0.02037
# Day 576 value: -54.46 todayPL: $-4.31 $-traded: 2462 return: -0.02212
# Day 577 value: -59.18 todayPL: $-4.72 $-traded: 2462 return: -0.02404
# Day 578 value: -54.50 todayPL: $4.68 $-traded: 2462 return: -0.02214
# Day 579 value: -55.89 todayPL: $-1.39 $-traded: 2462 return: -0.02270
# Day 580 value: -55.20 todayPL: $0.69 $-traded: 2462 return: -0.02242
# Day 581 value: -51.48 todayPL: $3.72 $-traded: 2462 return: -0.02091
# Day 582 value: -54.19 todayPL: $-2.71 $-traded: 2462 return: -0.02201
# Day 583 value: -53.39 todayPL: $0.80 $-traded: 2462 return: -0.02169
# Day 584 value: -55.36 todayPL: $-1.97 $-traded: 2462 return: -0.02249
# Day 585 value: -52.92 todayPL: $2.44 $-traded: 2462 return: -0.02150
# Day 586 value: -60.23 todayPL: $-7.31 $-traded: 2462 return: -0.02447
# Day 587 value: -61.15 todayPL: $-0.92 $-traded: 2462 return: -0.02484
# Day 588 value: -68.69 todayPL: $-7.54 $-traded: 2462 return: -0.02790
# Day 589 value: -71.27 todayPL: $-2.58 $-traded: 2462 return: -0.02895
# Day 590 value: -71.94 todayPL: $-0.67 $-traded: 2462 return: -0.02922
# Day 591 value: -71.30 todayPL: $0.64 $-traded: 2462 return: -0.02896
# Day 592 value: -77.65 todayPL: $-6.35 $-traded: 2462 return: -0.03154
# Day 593 value: -81.90 todayPL: $-4.25 $-traded: 2462 return: -0.03327
# Day 594 value: -83.66 todayPL: $-1.76 $-traded: 2462 return: -0.03398
# Day 595 value: -83.21 todayPL: $0.45 $-traded: 2462 return: -0.03380
# Day 596 value: -81.14 todayPL: $2.07 $-traded: 2462 return: -0.03296
# Day 597 value: -87.80 todayPL: $-6.66 $-traded: 2462 return: -0.03567
# Day 598 value: -92.78 todayPL: $-4.98 $-traded: 2462 return: -0.03769
# Day 599 value: -95.55 todayPL: $-2.77 $-traded: 2462 return: -0.03881
# Day 600 value: -98.20 todayPL: $-2.65 $-traded: 2462 return: -0.03989
# Day 601 value: -101.58 todayPL: $-3.38 $-traded: 2462 return: -0.04126
# Day 602 value: -98.33 todayPL: $3.25 $-traded: 2462 return: -0.03994
# Day 603 value: -90.49 todayPL: $7.84 $-traded: 2462 return: -0.03676
# Day 604 value: -88.45 todayPL: $2.04 $-traded: 2462 return: -0.03593
# Day 605 value: -89.99 todayPL: $-1.54 $-traded: 2462 return: -0.03656
# Day 606 value: -90.59 todayPL: $-0.60 $-traded: 2462 return: -0.03680
# Day 607 value: -95.87 todayPL: $-5.28 $-traded: 2462 return: -0.03894
# Day 608 value: -102.89 todayPL: $-7.02 $-traded: 2462 return: -0.04180
# Day 609 value: -107.39 todayPL: $-4.50 $-traded: 2462 return: -0.04362
# Day 610 value: -109.29 todayPL: $-1.90 $-traded: 2462 return: -0.04440
# Day 611 value: -108.69 todayPL: $0.60 $-traded: 2462 return: -0.04415
# Day 612 value: -109.17 todayPL: $-0.48 $-traded: 2462 return: -0.04435
# Day 613 value: -112.59 todayPL: $-3.42 $-traded: 2462 return: -0.04574
# Day 614 value: -113.64 todayPL: $-1.05 $-traded: 2462 return: -0.04616
# Day 615 value: -112.61 todayPL: $1.03 $-traded: 2462 return: -0.04574
# Day 616 value: -114.50 todayPL: $-1.89 $-traded: 2462 return: -0.04651
# Day 617 value: -116.12 todayPL: $-1.62 $-traded: 2462 return: -0.04717
# Day 618 value: -112.30 todayPL: $3.82 $-traded: 2462 return: -0.04562
# Day 619 value: -117.03 todayPL: $-4.73 $-traded: 2462 return: -0.04754
# Day 620 value: -118.21 todayPL: $-1.18 $-traded: 2462 return: -0.04802
# Day 621 value: -119.62 todayPL: $-1.41 $-traded: 2462 return: -0.04859
# Day 622 value: -118.77 todayPL: $0.85 $-traded: 2462 return: -0.04825
# Day 623 value: -122.53 todayPL: $-3.76 $-traded: 2462 return: -0.04977
# Day 624 value: -116.59 todayPL: $5.94 $-traded: 2462 return: -0.04736
# Day 625 value: -111.63 todayPL: $4.96 $-traded: 2462 return: -0.04535
# Day 626 value: -108.73 todayPL: $2.90 $-traded: 2462 return: -0.04417
# Day 627 value: -100.33 todayPL: $8.40 $-traded: 2462 return: -0.04076
# Day 628 value: -95.19 todayPL: $5.14 $-traded: 2462 return: -0.03867
# Day 629 value: -91.81 todayPL: $3.38 $-traded: 2462 return: -0.03730
# Day 630 value: -85.79 todayPL: $6.02 $-traded: 2462 return: -0.03485
# Day 631 value: -79.89 todayPL: $5.90 $-traded: 2462 return: -0.03245
# Day 632 value: -77.53 todayPL: $2.36 $-traded: 2462 return: -0.03149
# Day 633 value: -76.08 todayPL: $1.45 $-traded: 2462 return: -0.03091
# Day 634 value: -74.82 todayPL: $1.26 $-traded: 2462 return: -0.03039
# Day 635 value: -69.46 todayPL: $5.36 $-traded: 2462 return: -0.02822
# Day 636 value: -74.68 todayPL: $-5.22 $-traded: 2462 return: -0.03034
# Day 637 value: -72.97 todayPL: $1.71 $-traded: 2462 return: -0.02964
# Day 638 value: -78.36 todayPL: $-5.39 $-traded: 2462 return: -0.03183
# Day 639 value: -79.34 todayPL: $-0.98 $-traded: 2462 return: -0.03223
# Day 640 value: -79.04 todayPL: $0.30 $-traded: 2462 return: -0.03211
# Day 641 value: -75.45 todayPL: $3.59 $-traded: 2462 return: -0.03065
# Day 642 value: -73.62 todayPL: $1.83 $-traded: 2462 return: -0.02991
# Day 643 value: -75.72 todayPL: $-2.10 $-traded: 2462 return: -0.03076
# Day 644 value: -74.79 todayPL: $0.93 $-traded: 2462 return: -0.03038
# Day 645 value: -71.88 todayPL: $2.91 $-traded: 2462 return: -0.02920
# Day 646 value: -73.39 todayPL: $-1.51 $-traded: 2462 return: -0.02981
# Day 647 value: -72.26 todayPL: $1.13 $-traded: 2462 return: -0.02935
# Day 648 value: -71.57 todayPL: $0.69 $-traded: 2462 return: -0.02907
# Day 649 value: -72.01 todayPL: $-0.44 $-traded: 2462 return: -0.02925
# Day 650 value: -72.75 todayPL: $-0.74 $-traded: 2462 return: -0.02955
# Day 651 value: -69.34 todayPL: $3.41 $-traded: 2462 return: -0.02817
# Day 652 value: -67.90 todayPL: $1.44 $-traded: 2462 return: -0.02758
# Day 653 value: -59.22 todayPL: $8.68 $-traded: 2462 return: -0.02406
# Day 654 value: -54.28 todayPL: $4.94 $-traded: 2462 return: -0.02205
# Day 655 value: -51.19 todayPL: $3.09 $-traded: 2462 return: -0.02079
# Day 656 value: -48.55 todayPL: $2.64 $-traded: 2462 return: -0.01972
# Day 657 value: -45.38 todayPL: $3.17 $-traded: 2462 return: -0.01843
# Day 658 value: -45.48 todayPL: $-0.10 $-traded: 2462 return: -0.01848
# Day 659 value: -41.07 todayPL: $4.41 $-traded: 2462 return: -0.01668
# Day 660 value: -41.31 todayPL: $-0.24 $-traded: 2462 return: -0.01678
# Day 661 value: -37.48 todayPL: $3.83 $-traded: 2462 return: -0.01523
# Day 662 value: -39.55 todayPL: $-2.07 $-traded: 2462 return: -0.01607
# Day 663 value: -40.48 todayPL: $-0.93 $-traded: 2462 return: -0.01644
# Day 664 value: -37.98 todayPL: $2.50 $-traded: 2462 return: -0.01543
# Day 665 value: -37.33 todayPL: $0.65 $-traded: 2462 return: -0.01516
# Day 666 value: -41.67 todayPL: $-4.34 $-traded: 2462 return: -0.01693
# Day 667 value: -42.39 todayPL: $-0.72 $-traded: 2462 return: -0.01722
# Day 668 value: -46.30 todayPL: $-3.91 $-traded: 2462 return: -0.01881
# Day 669 value: -50.30 todayPL: $-4.00 $-traded: 2462 return: -0.02043
# Day 670 value: -57.39 todayPL: $-7.09 $-traded: 2462 return: -0.02331
# Day 671 value: -63.04 todayPL: $-5.65 $-traded: 2462 return: -0.02561
# Day 672 value: -62.98 todayPL: $0.06 $-traded: 2462 return: -0.02558
# Day 673 value: -59.91 todayPL: $3.07 $-traded: 2462 return: -0.02434
# Day 674 value: -54.35 todayPL: $5.56 $-traded: 2462 return: -0.02208
# Day 675 value: -54.03 todayPL: $0.32 $-traded: 2462 return: -0.02195
# Day 676 value: -51.58 todayPL: $2.45 $-traded: 2462 return: -0.02095
# Day 677 value: -55.65 todayPL: $-4.07 $-traded: 2462 return: -0.02261
# Day 678 value: -61.08 todayPL: $-5.43 $-traded: 2462 return: -0.02481
# Day 679 value: -63.00 todayPL: $-1.92 $-traded: 2462 return: -0.02559
# Day 680 value: -66.47 todayPL: $-3.47 $-traded: 2462 return: -0.02700
# Day 681 value: -66.44 todayPL: $0.03 $-traded: 2462 return: -0.02699
# Day 682 value: -67.69 todayPL: $-1.25 $-traded: 2462 return: -0.02750
# Day 683 value: -71.50 todayPL: $-3.81 $-traded: 2462 return: -0.02905
# Day 684 value: -78.06 todayPL: $-6.56 $-traded: 2462 return: -0.03171
# Day 685 value: -75.06 todayPL: $3.00 $-traded: 2462 return: -0.03049
# Day 686 value: -72.37 todayPL: $2.69 $-traded: 2462 return: -0.02940
# Day 687 value: -71.06 todayPL: $1.31 $-traded: 2462 return: -0.02887
# Day 688 value: -69.39 todayPL: $1.67 $-traded: 2462 return: -0.02819
# Day 689 value: -74.93 todayPL: $-5.54 $-traded: 2462 return: -0.03044
# Day 690 value: -78.11 todayPL: $-3.18 $-traded: 2462 return: -0.03173
# Day 691 value: -85.24 todayPL: $-7.13 $-traded: 2462 return: -0.03463
# Day 692 value: -91.73 todayPL: $-6.49 $-traded: 2462 return: -0.03726
# Day 693 value: -84.35 todayPL: $7.38 $-traded: 2462 return: -0.03427
# Day 694 value: -82.67 todayPL: $1.68 $-traded: 2462 return: -0.03358
# Day 695 value: -83.47 todayPL: $-0.80 $-traded: 2462 return: -0.03391
# Day 696 value: -87.29 todayPL: $-3.82 $-traded: 2462 return: -0.03546
# Day 697 value: -89.23 todayPL: $-1.94 $-traded: 2462 return: -0.03625
# Day 698 value: -91.12 todayPL: $-1.89 $-traded: 2462 return: -0.03702
# Day 699 value: -87.70 todayPL: $3.42 $-traded: 2462 return: -0.03563
# Day 700 value: -84.24 todayPL: $3.46 $-traded: 2462 return: -0.03422
# Day 701 value: -79.49 todayPL: $4.75 $-traded: 2462 return: -0.03229
# Day 702 value: -80.40 todayPL: $-0.91 $-traded: 2462 return: -0.03266
# Day 703 value: -84.35 todayPL: $-3.95 $-traded: 2462 return: -0.03427
# Day 704 value: -91.87 todayPL: $-7.52 $-traded: 2462 return: -0.03732
# Day 705 value: -96.26 todayPL: $-4.39 $-traded: 2462 return: -0.03910
# Day 706 value: -91.19 todayPL: $5.07 $-traded: 2462 return: -0.03704
# Day 707 value: -80.85 todayPL: $10.34 $-traded: 2462 return: -0.03284
# Day 708 value: -76.92 todayPL: $3.93 $-traded: 2462 return: -0.03125
# Day 709 value: -72.54 todayPL: $4.38 $-traded: 2462 return: -0.02947
# Day 710 value: -68.62 todayPL: $3.92 $-traded: 2462 return: -0.02788
# Day 711 value: -71.84 todayPL: $-3.22 $-traded: 2462 return: -0.02918
# Day 712 value: -77.62 todayPL: $-5.78 $-traded: 2462 return: -0.03153
# Day 713 value: -79.06 todayPL: $-1.44 $-traded: 2462 return: -0.03212
# Day 714 value: -78.19 todayPL: $0.87 $-traded: 2462 return: -0.03176
# Day 715 value: -76.92 todayPL: $1.27 $-traded: 2462 return: -0.03125
# Day 716 value: -74.83 todayPL: $2.09 $-traded: 2462 return: -0.03040
# Day 717 value: -69.73 todayPL: $5.10 $-traded: 2462 return: -0.02833
# Day 718 value: -70.62 todayPL: $-0.89 $-traded: 2462 return: -0.02869
# Day 719 value: -68.73 todayPL: $1.89 $-traded: 2462 return: -0.02792
# Day 720 value: -64.54 todayPL: $4.19 $-traded: 2462 return: -0.02622
# Day 721 value: -62.36 todayPL: $2.18 $-traded: 2462 return: -0.02533
# Day 722 value: -60.93 todayPL: $1.43 $-traded: 2462 return: -0.02475
# Day 723 value: -57.33 todayPL: $3.60 $-traded: 2462 return: -0.02329
# Day 724 value: -47.65 todayPL: $9.68 $-traded: 2462 return: -0.01936
# Day 725 value: -40.38 todayPL: $7.27 $-traded: 2462 return: -0.01640
# Day 726 value: -41.92 todayPL: $-1.54 $-traded: 2462 return: -0.01703
# Day 727 value: -41.54 todayPL: $0.38 $-traded: 2462 return: -0.01687
# Day 728 value: -43.46 todayPL: $-1.92 $-traded: 2462 return: -0.01765
# Day 729 value: -43.69 todayPL: $-0.23 $-traded: 2462 return: -0.01775
# Day 730 value: -41.47 todayPL: $2.22 $-traded: 2462 return: -0.01685
# Day 731 value: -44.78 todayPL: $-3.31 $-traded: 2462 return: -0.01819
# Day 732 value: -42.63 todayPL: $2.15 $-traded: 2462 return: -0.01732
# Day 733 value: -39.19 todayPL: $3.44 $-traded: 2462 return: -0.01592
# Day 734 value: -39.38 todayPL: $-0.19 $-traded: 2462 return: -0.01600
# Day 735 value: -38.78 todayPL: $0.60 $-traded: 2462 return: -0.01575
# Day 736 value: -38.98 todayPL: $-0.20 $-traded: 2462 return: -0.01583
# Day 737 value: -38.26 todayPL: $0.72 $-traded: 2462 return: -0.01554
# Day 738 value: -41.80 todayPL: $-3.54 $-traded: 2462 return: -0.01698
# Day 739 value: -49.63 todayPL: $-7.83 $-traded: 2462 return: -0.02016
# Day 740 value: -51.63 todayPL: $-2.00 $-traded: 2462 return: -0.02097
# Day 741 value: -49.50 todayPL: $2.13 $-traded: 2462 return: -0.02011
# Day 742 value: -52.24 todayPL: $-2.74 $-traded: 2462 return: -0.02122
# Day 743 value: -51.09 todayPL: $1.15 $-traded: 2462 return: -0.02075
# Day 744 value: -51.11 todayPL: $-0.02 $-traded: 2462 return: -0.02076
# Day 745 value: -54.56 todayPL: $-3.45 $-traded: 2462 return: -0.02216
# Day 746 value: -56.47 todayPL: $-1.91 $-traded: 2462 return: -0.02294
# Day 747 value: -59.45 todayPL: $-2.98 $-traded: 2462 return: -0.02415
# Day 748 value: -57.15 todayPL: $2.30 $-traded: 2462 return: -0.02322
# Day 749 value: -58.87 todayPL: $-1.72 $-traded: 2462 return: -0.02391
# Day 750 value: -57.78 todayPL: $1.09 $-traded: 2462 return: -0.02347
# =====
# Function: simple_long_position
# mean(PL): -0.3
# return: -0.02347
# StdDev(PL): 3.77
# annSharpe(PL): -1.19
# totDvolume: 2462
# Score: -0.66
# =====

# %%
@backtest()
def momentum_strategy(prcHistSoFar):
    """Simple momentum strategy"""
    nInst, nt = prcHistSoFar.shape
    if nt < 2:
        return np.zeros(nInst)
    
    # Calculate recent returns
    recent_returns = (prcHistSoFar[:, -1] - prcHistSoFar[:, -2]) / prcHistSoFar[:, -2]
    
    # Go long on positive momentum, short on negative
    positions = np.sign(recent_returns)
    return positions

# %%
@backtest()
def mean_reversion_strategy(prcHistSoFar):
    """Simple mean reversion strategy"""
    nInst, nt = prcHistSoFar.shape
    if nt < 10:
        return np.zeros(nInst)
    
    # Calculate deviation from 10-day mean
    recent_mean = np.mean(prcHistSoFar[:, -10:], axis=1)
    current_price = prcHistSoFar[:, -1]
    deviation = (current_price - recent_mean) / recent_mean
    
    # Go opposite to deviation (mean reversion)
    positions = -np.sign(deviation)
    return positions
# Out:
# Testing function: mean_reversion_strategy
# Day 552 value: 1.18 todayPL: $2.41 $-traded: 3522 return: 0.00033
# Day 553 value: -1.76 todayPL: $-2.94 $-traded: 3899 return: -0.00045
# Day 554 value: 0.52 todayPL: $2.28 $-traded: 4934 return: 0.00011
# Day 555 value: -0.34 todayPL: $-0.86 $-traded: 5520 return: -0.00006
# Day 556 value: 1.08 todayPL: $1.42 $-traded: 6741 return: 0.00016
# Day 557 value: 4.61 todayPL: $3.53 $-traded: 8202 return: 0.00056
# Day 558 value: 3.92 todayPL: $-0.68 $-traded: 9031 return: 0.00043
# Day 559 value: 7.05 todayPL: $3.12 $-traded: 10290 return: 0.00068
# Day 560 value: 9.94 todayPL: $2.90 $-traded: 11572 return: 0.00086
# Day 561 value: 6.74 todayPL: $-3.20 $-traded: 12342 return: 0.00055
# Day 562 value: 7.17 todayPL: $0.44 $-traded: 13291 return: 0.00054
# Day 563 value: 9.84 todayPL: $2.66 $-traded: 14502 return: 0.00068
# Day 564 value: 13.21 todayPL: $3.37 $-traded: 16032 return: 0.00082
# Day 565 value: 11.50 todayPL: $-1.72 $-traded: 17288 return: 0.00066
# Day 566 value: 9.58 todayPL: $-1.92 $-traded: 17929 return: 0.00053
# Day 567 value: 6.45 todayPL: $-3.13 $-traded: 18744 return: 0.00034
# Day 568 value: 2.21 todayPL: $-4.23 $-traded: 19552 return: 0.00011
# Day 569 value: 0.40 todayPL: $-1.82 $-traded: 20303 return: 0.00002
# Day 570 value: 0.09 todayPL: $-0.31 $-traded: 20997 return: 0.00000
# Day 610 value: -10.86 todayPL: $7.27 $-traded: 56808 return: -0.00019
# Day 611 value: -4.92 todayPL: $5.95 $-traded: 57955 return: -0.00008
# Day 612 value: -5.81 todayPL: $-0.90 $-traded: 59066 return: -0.00010
# Day 613 value: -5.51 todayPL: $0.31 $-traded: 60056 return: -0.00009
# Day 614 value: -6.30 todayPL: $-0.79 $-traded: 60976 return: -0.00010
# Day 615 value: -6.62 todayPL: $-0.32 $-traded: 61879 return: -0.00011
# Day 616 value: -6.68 todayPL: $-0.06 $-traded: 63453 return: -0.00011
# Day 617 value: -6.88 todayPL: $-0.21 $-traded: 64188 return: -0.00011
# Day 618 value: -2.82 todayPL: $4.06 $-traded: 65587 return: -0.00004
# Day 619 value: -2.82 todayPL: $0.01 $-traded: 66632 return: -0.00004
# Day 620 value: -6.78 todayPL: $-3.96 $-traded: 67675 return: -0.00010
# Day 621 value: -3.52 todayPL: $3.25 $-traded: 68666 return: -0.00005
# Day 622 value: -1.97 todayPL: $1.56 $-traded: 69935 return: -0.00003
# Day 623 value: -5.90 todayPL: $-3.93 $-traded: 70681 return: -0.00008
# Day 624 value: -5.68 todayPL: $0.22 $-traded: 71312 return: -0.00008
# Day 625 value: -6.87 todayPL: $-1.19 $-traded: 72132 return: -0.00010
# Day 626 value: -8.26 todayPL: $-1.40 $-traded: 73009 return: -0.00011
# Day 627 value: -8.67 todayPL: $-0.41 $-traded: 74142 return: -0.00012
# Day 628 value: -17.17 todayPL: $-8.50 $-traded: 74430 return: -0.00023
# Day 629 value: -24.13 todayPL: $-6.95 $-traded: 75059 return: -0.00032
# Day 630 value: -25.50 todayPL: $-1.37 $-traded: 75955 return: -0.00034
# Day 631 value: -31.39 todayPL: $-5.89 $-traded: 76455 return: -0.00041
# Day 632 value: -30.90 todayPL: $0.49 $-traded: 76844 return: -0.00040
# Day 633 value: -32.06 todayPL: $-1.16 $-traded: 77508 return: -0.00041
# Day 634 value: -30.70 todayPL: $1.36 $-traded: 78979 return: -0.00039
# Day 635 value: -36.29 todayPL: $-5.59 $-traded: 79738 return: -0.00046
# Day 636 value: -30.07 todayPL: $6.22 $-traded: 81143 return: -0.00037
# Day 637 value: -39.66 todayPL: $-9.59 $-traded: 81822 return: -0.00048
# Day 638 value: -41.64 todayPL: $-1.97 $-traded: 82311 return: -0.00051
# Day 639 value: -40.61 todayPL: $1.02 $-traded: 83309 return: -0.00049
# Day 640 value: -39.32 todayPL: $1.29 $-traded: 83964 return: -0.00047
# Day 641 value: -44.43 todayPL: $-5.11 $-traded: 84634 return: -0.00052
# Day 642 value: -49.14 todayPL: $-4.71 $-traded: 85151 return: -0.00058
# Day 643 value: -48.67 todayPL: $0.46 $-traded: 86029 return: -0.00057
# Day 644 value: -48.37 todayPL: $0.31 $-traded: 86874 return: -0.00056
# Day 645 value: -47.61 todayPL: $0.76 $-traded: 87372 return: -0.00054
# Day 646 value: -46.83 todayPL: $0.78 $-traded: 88436 return: -0.00053
# Day 647 value: -50.39 todayPL: $-3.57 $-traded: 88987 return: -0.00057
# Day 648 value: -55.11 todayPL: $-4.72 $-traded: 89650 return: -0.00061
# Day 649 value: -57.12 todayPL: $-2.01 $-traded: 90342 return: -0.00063
# Day 728 value: -35.65 todayPL: $0.11 $-traded: 161729 return: -0.00022
# Day 729 value: -37.10 todayPL: $-1.45 $-traded: 162643 return: -0.00023
# Day 730 value: -35.19 todayPL: $1.91 $-traded: 163268 return: -0.00022
# Day 731 value: -41.64 todayPL: $-6.45 $-traded: 163978 return: -0.00025
# Day 732 value: -36.46 todayPL: $5.18 $-traded: 165245 return: -0.00022
# Day 733 value: -43.63 todayPL: $-7.17 $-traded: 165742 return: -0.00026
# Day 734 value: -47.96 todayPL: $-4.33 $-traded: 165982 return: -0.00029
# Day 735 value: -46.59 todayPL: $1.37 $-traded: 166529 return: -0.00028
# Day 736 value: -43.82 todayPL: $2.78 $-traded: 167416 return: -0.00026
# Day 737 value: -45.90 todayPL: $-2.08 $-traded: 168373 return: -0.00027
# Day 738 value: -49.21 todayPL: $-3.31 $-traded: 168915 return: -0.00029
# Day 739 value: -49.56 todayPL: $-0.35 $-traded: 169637 return: -0.00029
# Day 740 value: -53.39 todayPL: $-3.83 $-traded: 170221 return: -0.00031
# Day 741 value: -52.10 todayPL: $1.29 $-traded: 171549 return: -0.00030
# Day 742 value: -56.28 todayPL: $-4.18 $-traded: 172386 return: -0.00033
# Day 743 value: -59.59 todayPL: $-3.31 $-traded: 173178 return: -0.00034
# Day 744 value: -62.77 todayPL: $-3.19 $-traded: 173829 return: -0.00036
# Day 745 value: -65.27 todayPL: $-2.49 $-traded: 174592 return: -0.00037
# Day 746 value: -63.65 todayPL: $1.61 $-traded: 175664 return: -0.00036
# Day 747 value: -68.07 todayPL: $-4.42 $-traded: 176500 return: -0.00039
# Day 748 value: -72.55 todayPL: $-4.48 $-traded: 176946 return: -0.00041
# Day 749 value: -72.46 todayPL: $0.09 $-traded: 177330 return: -0.00041
# Day 750 value: -69.81 todayPL: $2.65 $-traded: 177330 return: -0.00039
# =====
# Function: mean_reversion_strategy
# mean(PL): -0.3
# return: -0.00039
# StdDev(PL): 3.25
# annSharpe(PL): -1.67
# totDvolume: 177330
# Score: -0.67
# =====

# %%
@backtest(10)
def getPosition(prices):
    return [1] * len(prices)
# Out:
# Testing function: getPosition
# Day 742 value: -3.95 todayPL: $-2.74 $-traded: 2413 return: -0.00164
# Day 743 value: -2.80 todayPL: $1.15 $-traded: 2413 return: -0.00116
# Day 744 value: -2.82 todayPL: $-0.02 $-traded: 2413 return: -0.00117
# Day 745 value: -6.27 todayPL: $-3.45 $-traded: 2413 return: -0.00260
# Day 746 value: -8.18 todayPL: $-1.91 $-traded: 2413 return: -0.00339
# Day 747 value: -11.16 todayPL: $-2.98 $-traded: 2413 return: -0.00462
# Day 748 value: -8.86 todayPL: $2.30 $-traded: 2413 return: -0.00367
# Day 749 value: -10.58 todayPL: $-1.72 $-traded: 2413 return: -0.00438
# Day 750 value: -9.49 todayPL: $1.09 $-traded: 2413 return: -0.00393
# =====
# Function: getPosition
# mean(PL): -0.9
# return: -0.00393
# StdDev(PL): 1.97
# annSharpe(PL): -7.35
# totDvolume: 2413
# Score: -1.12
# =====

# %%
# A bunch of basic algos that can be used as samples:
# 1: If trend continues for n consecutive days, position moves by n steps
